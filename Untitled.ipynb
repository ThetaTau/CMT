# %%
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "config.settings.local")
# Out:
# 'config.settings.local'

# %%
import django

# %%
django.setup()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_88/4256331104.py in <module>
# ----> 1 django.setup()
#
# /usr/local/lib/python3.9/site-packages/django/__init__.py in setup(set_prefix)
#      22             '/' if settings.FORCE_SCRIPT_NAME is None else settings.FORCE_SCRIPT_NAME
#      23         )
# ---> 24     apps.populate(settings.INSTALLED_APPS)
#
# /usr/local/lib/python3.9/site-packages/django/apps/registry.py in populate(self, installed_apps)
#      81                 # Prevent reentrant calls to avoid running AppConfig.ready()
#      82                 # methods twice.
# ---> 83                 raise RuntimeError("populate() isn't reentrant")
#      84             self.loading = True
#      85
#
# RuntimeError: populate() isn't reentrant
